# %%
a=55
print(a)
# Out:
# 55

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
a
# Out:
# 55

# %%
a
# Out:
# 55

# %%
a
# Out:
# 55

# %%
type(a)
# Out:
# int

# %%
b=4.5
b
# Out:
# 4.5

# %%
type(b)
# Out:
# float

# %%
b
# Out:
# 4.5

# %%
b
# Out:
# 4.5

# %%
b
# Out:
# 4.5

# %%
print(type(b))
# Out:
# <class 'float'>

# %%
print(b)
# Out:
# 4.5

# %%
print(a)
# Out:
# 55

# %%
print(b)
# Out:
# 4.5

# %%
type(a)
# Out:
# int

# %%
print(type(b))
# Out:
# <class 'float'>

# %%
a
# Out:
# 55

# %%
a
# Out:
# 55

# %%
b
# Out:
# 4.5

# %%
b
# Out:
# 4.5

# %%
b
# Out:
# 4.5

# %%
b
# Out:
# 4.5

# %%
a
# Out:
# 55
